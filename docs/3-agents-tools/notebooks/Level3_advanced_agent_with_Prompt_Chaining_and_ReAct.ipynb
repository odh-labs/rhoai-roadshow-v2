# %% [markdown]
# # Level 3: Advanced Agent Capabilities with Prompt Chaining and ReAct Agent
#
# Building on the simple agent introduced in [Level 1](Level1_simple_agent_with_websearch.ipynb), this tutorial continues the agent-focused section of our series by introducing techniques that make the agent smarter and more autonomous: **Prompt Chaining** and the **ReAct (Reasoning + Acting) framework**. These approaches allow the agent to complete multi-step tasks, dynamically choose tools, and adjust its behavior based on context.
#
# - **Prompt Chaining** connects multiple prompts into a coherent sequence, allowing the agent to maintain context and perform multi-step reasoning across tool invocations.
# - **ReAct Agent** combines reasoning and acting steps in a loop, enabling the agent to make decisions, use tools dynamically, and adapt based on intermediate results.
#
# ## Overview
#
# In this notebook, you'll explore three agent configurations:
# 1. **Simple Agent (Baseline)** – Uses a single web search tool.
# 2. **Prompt Chaining** – Performs structured, multi-step reasoning by chaining prompts and responses.
# 3. **ReAct Agent** – Dynamically plans and executes actions using a loop of reasoning and tool use.
#
#
# ## Prerequisites
#
# Before starting this notebook, ensure that you have:
# - Followed the instructions in the [Setup Guide](./Level1_getting_started_with_Llama_Stack.ipynb) notebook.
# - A Tavily API key. It is critical for this notebook to run correctly. You can register for one at [https://tavily.com/](https://tavily.com/).
#
# Add your TAVILY_SEARCH_API_KEY="tvly-dev-your-key" to the `env.example` file.

# %% [markdown]
# ## 1. Setting Up this Notebook
# We will start with a few imports needed for this demo only.

# %%
from llama_stack_client import Agent
from llama_stack_client.lib.agents.event_logger import EventLogger
from llama_stack_client.lib.agents.react.agent import ReActAgent
from llama_stack_client.lib.agents.react.tool_parser import ReActOutput
import sys
sys.path.append('.') 
from src.client_tools import get_location

# %% [markdown]
# Next, we will initialize our environment as described in detail in our ["Getting Started" notebook](./Level1_getting_started_with_Llama_Stack.ipynb). Please refer to it for additional explanations.

# %%
# for accessing the environment variables
import os
from dotenv import load_dotenv
load_dotenv(override=True)

# for communication with Llama Stack
from llama_stack_client import LlamaStackClient

# pretty print of the results returned from the model/agent
import sys
sys.path.append('.')  
from src.utils import step_printer
from termcolor import cprint

base_url = os.getenv("REMOTE_BASE_URL")


# Tavily search API key is required for some of our demos and must be provided to the client upon initialization.
# We will cover it in the agentic demos that use the respective tool. Please ignore this parameter for all other demos.
tavily_search_api_key = os.getenv("TAVILY_SEARCH_API_KEY")
if len(tavily_search_api_key) != 41:
    raise ValueError("Sorry your Tavily Search key seems invalid?")
else:
    provider_data = {"tavily_search_api_key": tavily_search_api_key}


client = LlamaStackClient(
    base_url=base_url,
    provider_data=provider_data
)
    
print(f"Connected to Llama Stack server")

# model_id for the model you wish to use that is configured with the Llama Stack server
model_id = "llama3-2-3b" # "deepseek-r1-0528-qwen3-8b-bnb-4bit", "llama-4-scout-17b-16e-w4a16"

temperature = float(os.getenv("TEMPERATURE", 0.0))
if temperature > 0.0:
    top_p = float(os.getenv("TOP_P", 0.95))
    strategy = {"type": "top_p", "temperature": temperature, "top_p": top_p}
else:
    strategy = {"type": "greedy"}

max_tokens = 5000

# sampling_params will later be used to pass the parameters to Llama Stack Agents/Inference APIs
sampling_params = {
    "strategy": strategy,
    "max_tokens": max_tokens,
}

stream = "True"

print(f"Inference Parameters:\n\tModel: {model_id}\n\tSampling Parameters: {sampling_params}\n\tstream: {stream}")
# Out:
# Connected to Llama Stack server
# Inference Parameters:
# 	Model: llama3-2-3b
# 	Sampling Parameters: {'strategy': {'type': 'greedy'}, 'max_tokens': 5000}
# 	stream: True

# %% [markdown]
# ## 2. Simple Agent (Baseline)
# Same agent setup as [Level 2 notebook](Level2_simple_agent_with_websearch.ipynb).

# %%
agent = Agent(
    client, 
    model=model_id,
    instructions="""You are a helpful websearch assistant. When you are asked to search the latest you must use a tool. 
            Whenever a tool is called, be sure return the response in a friendly and helpful tone.
            """ ,
    tools=["builtin::websearch"],
    sampling_params=sampling_params
)
user_prompts = [
    "Are there any immediate weather-related risks in my area that could disrupt network connectivity or system availability?",
]
for prompt in user_prompts:
    print("\n"+"="*50)
    cprint(f"Processing user query: {prompt}", "blue")
    print("="*50)
    session_id = agent.create_session("web-session")
    response = agent.create_turn(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        session_id=session_id,
        stream=stream
    )
    if stream:
        for log in EventLogger().log(response):
            log.print()
    else:
        step_printer(response.steps) # print the steps of an agent's response in a formatted way.
# Out:
# ==================================================
# Processing user query: Are there any immediate weather-related risks in my area that could disrupt network connectivity or system availability?
# ==================================================
# inference>
# tool_execution> Tool:brave_search Args:{'query': 'weather-related risks in my area'}
# tool_execution> Tool:brave_search Response:{"query": "weather-related risks in my area", "top_k": [{"title": "Weather in my area", "url": "https://www.weatherapi.com/", "content": "{'location': {'name': 'Brighton Area', 'region': 'Sarawak', 'country': 'Malaysia', 'lat': 4.3833, 'lon': 113.9667, 'tz_id': 'Asia/Kuching', 'localtime_epoch': 1753578450, 'localtime': '2025-07-27 09:07'}, 'current': {'last_updated_epoch': 1753578000, 'last_updated': '2025-07-27 09:00', 'temp_c': 28.4, 'temp_f': 83.1, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 177, 'wind_dir': 'S', 'pressure_mb': 1011.0, 'pressure_in': 29.84, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 76, 'cloud': 7, 'feelslike_c': 32.6, 'feelslike_f': 90.6, 'windchill_c': 28.4, 'windchill_f': 83.1, 'heatindex_c': 32.6, 'heatindex_f': 90.6, 'dewpoint_c': 23.8, 'dewpoint_f': 74.8, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 4.1, 'gust_mph': 5.0, 'gust_kph': 8.0}}", "score": 0.9249314, "raw_content": null}, {"url": "https://www.scientificamerican.com/article/heat-domes-extreme-heat-and-humidity-triggers-alerts-across-eastern-u-s/", "title": "Millions Swelter under Relentless Heat Dome Smothering Eastern US", "content": "HeatRisk forecast for July 27, 2025. The NWS HeatRisk is an experimental color-numeric-based index that provides a forecast risk of heat-related", "score": 0.75268626, "raw_content": null}, {"url": "https://www.noaa.gov/weather-prediction-center", "title": "Weather Prediction Center (WPC) Home Page - NOAA", "content": "Snell Day 1 threat area: www.wpc.ncep.noaa.gov/qpf/94epoints.txt Excessive Rainfall Discussion NWS Weather Prediction Center College Park MD 404 AM EDT Thu Jul 24 2025 Day 1 Valid 12Z Thu Jul 24 2025 - 12Z Fri Jul 25 2025 ...THERE IS A SLIGHT RISK OF EXCESSIVE RAINFALL FROM THE CENTRAL AND SOUTHERN HIGH PLAINS INTO THE MIDWEST... Kleebauer Day 2 threat area: www.wpc.ncep.noaa.gov/qpf/98epoints.txt Excessive Rainfall Discussion NWS Weather Prediction Center College Park MD 404 AM EDT Thu Jul 24 2025 Day 3 Valid 12Z Sat Jul 26 2025 - 12Z Sun Jul 27 2025 ...THERE IS A MARGINAL RISK OF EXCESSIVE RAINFALL FOR PORTIONS OF THE GREAT LAKES, OHIO VALLEY, NORTHERN PLAINS, WESTERN AND CENTRAL GULF COAST, NORTHEAST CALIFORNIA AND NORTHWEST NEVADA...", "score": 0.53619206, "raw_content": null}, {"url": "https://www.weather.gov/tsa/", "title": "Tulsa, OK - National Weather Service", "content": "Missing: 27/07/2025", "score": 0.45072258, "raw_content": null}, {"url": "https://www.newson6.com/weather", "title": "Weather Forecast for Tulsa, Oklahoma - News On 6", "content": "Outlook for Saturday, July 26 2025 \u00b7 96\u00b0 \u00b7 S 8 MPH ; Outlook for Sunday, July 27 2025 \u00b7 96\u00b0 \u00b7 S 8 MPH ; Outlook for Monday, July 28 2025 \u00b7 98\u00b0 \u00b7 SSW 7 MPH ; Outlook for", "score": 0.3135884, "raw_content": null}]}
# inference> Based on the search results, it appears that there are no immediate weather-related risks in your area that could disrupt network connectivity or system availability. The current weather conditions in your area are sunny with a temperature of 28.4°C (83.1°F) and a wind speed of 4.3 mph (6.8 km/h). There is no forecast for extreme heat or humidity that could pose a risk to network connectivity or system availability.
#
# However, it's always a good idea to check the weather forecast regularly to stay informed about any potential weather-related issues that may affect your area. You can check the weather forecast on websites such as weather.gov or weather.com for the most up-to-date information.

# %% [markdown]
# ### Output Analysis
#
# In this example, since the agent is unaware of the users location, it hallucinates one and generates an incorrect search query. This misidentification leads to inaccurate information about potential weather-related risks.
#
# This is where Prompt Chaining comes in. Prompt chaining allows the agent to:
# 1. Maintain context across multiple queries
# 2. Chain multiple tools together
# 3. Use previous interactions to inform current decisions
#
# Let’s see how prompt chaining can improve the accuracy of the response.

# %% [markdown]
# ## 3. Prompt chaining with websearch tool and client tool
#
# In this section, we demonstrate a more sophisticated use case that combines the use of two tools: location detection and web search.
#
# 1. **Automatic Location Detection**: Use the `get_location` client tool (have a look in the src folder `client_tools.py`) to automatically determine the user's current location.
# 2. **Contextual Search**: Leverage the detected location to formulate the correct websearch query.
#
# For example, when a user asks "Are there any weather-related risks in my area that could disrupt network connectivity or system availability?", the agent will:
# - First detect the user's current location using `get_location`.
# - Then use that location to search for nearby weather-related risks.
# - Finally, present a comprehensive response.
#
# This demonstrates how the builtin websearch tool and custom client tools can work together to provide intelligent, context-aware responses without requiring explicit location input from the user.

# %%
agent = Agent(
    client, 
    model=model_id,
    instructions="""You are a helpful assistant. 
    When a user asks about their location, you MUST use the get_location tool. When you are asked to search the latest news, you MUST use the websearch tool.
    """ ,
    tools=[get_location, "builtin::websearch"],
    sampling_params=sampling_params
)
user_prompts = [
    "Where am I?",
    "Are there any immediate weather-related risks in my area that could disrupt network connectivity or system availability?"
]
session_id = agent.create_session("prompt-chaining-session")  # for prompt chaining, queries must share the same session_id.
for prompt in user_prompts:
    print("\n"+"="*50)
    cprint(f"Processing user query: {prompt}", "blue")
    print("="*50)
    response = agent.create_turn(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        session_id=session_id,
        stream=stream
    )

    if stream:
        for log in EventLogger().log(response):
            log.print()
    else:
        step_printer(response.steps) # print the steps of an agent's response in a formatted way.
# Out:
# ==================================================
# Processing user query: Where am I?
# ==================================================
# inference>
# tool_execution> Tool:get_location Args:{'query': 'location'}
# tool_execution> Tool:get_location Response:"Your current location is: Sydney, New South Wales, AU"
# inference>
# tool_execution> Tool:get_location Args:{'query': 'location'}
# tool_execution> Tool:get_location Response:"Your current location is: Sydney, New South Wales, AU"
# inference>
# tool_execution> Tool:brave_search Args:{'query': 'latest news'}
# tool_execution> Tool:brave_search Response:{"query": "latest news", "top_k": [{"url": "https://news.yahoo.com/", "title": "Yahoo News: Latest and Breaking News, Headlines, Live Updates ...", "content": "The latest news and headlines from Yahoo News. Get breaking news stories and in-depth coverage with videos and photos.", "score": 0.5274388, "raw_content": null}, {"url": "https://www.foxnews.com/", "title": "Fox News - Breaking News Updates | Latest News Headlines ...", "content": "Breaking News, Latest News and Current News from FOXNews.com. Breaking news and video. Latest Current News: U.S., World, Entertainment, Health, Business,", "score": 0.5253938, "raw_content": null}, {"url": "https://www.cnn.com/", "title": "CNN: Breaking News, Latest News and Videos", "content": "View the latest news and breaking news today for U.S., world, weather, entertainment, politics and health at CNN.com.", "score": 0.49919498, "raw_content": null}, {"url": "https://abcnews.go.com/", "title": "ABC News - Breaking News, Latest News and Videos", "content": "Walmart voluntarily recalls thousands of water bottles over potential injury risk \u00b7 DuPont agrees to $27M settlement in water lawsuit \u00b7 Bitcoin tops $118,000", "score": 0.45522344, "raw_content": null}, {"url": "https://www.nbcnews.com/", "title": "NBC News - Breaking News & Top Stories - Latest World, US ...", "content": "Go to NBCNews.com for breaking news, videos, and the latest top stories in world news, business, politics, health and pop culture.", "score": 0.41506538, "raw_content": null}]}
# inference> I can't provide real-time information, but I can give you a list of news sources. Would you like me to provide you with a list of news sources?
#
# ==================================================
# Processing user query: Are there any immediate weather-related risks in my area that could disrupt network connectivity or system availability?
# ==================================================
# inference>
# tool_execution> Tool:brave_search Args:{'query': 'weather risks in Sydney, New South Wales, AU'}
# tool_execution> Tool:brave_search Response:{"query": "weather risks in Sydney, New South Wales, AU", "top_k": [{"title": "Weather in Sydney, New South Wales, AU", "url": "https://www.weatherapi.com/", "content": "{'location': {'name': 'Sydney', 'region': 'New South Wales', 'country': 'Australia', 'lat': -33.8833, 'lon': 151.2167, 'tz_id': 'Australia/Sydney', 'localtime_epoch': 1753577690, 'localtime': '2025-07-27 10:54'}, 'current': {'last_updated_epoch': 1753577100, 'last_updated': '2025-07-27 10:45', 'temp_c': 14.6, 'temp_f': 58.3, 'is_day': 1, 'condition': {'text': 'Partly Cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 15.7, 'wind_kph': 25.2, 'wind_degree': 319, 'wind_dir': 'NW', 'pressure_mb': 1006.0, 'pressure_in': 29.71, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 60, 'cloud': 29, 'feelslike_c': 12.8, 'feelslike_f': 55.1, 'windchill_c': 12.8, 'windchill_f': 55.1, 'heatindex_c': 14.6, 'heatindex_f': 58.3, 'dewpoint_c': 7.0, 'dewpoint_f': 44.6, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.6, 'gust_mph': 19.3, 'gust_kph': 31.0}}", "score": 0.8928792, "raw_content": null}, {"url": "https://watchers.news/2025/07/23/rain-australia-major-weather-system-july-2025/", "title": "Rain expected across most of Australia as major weather system ...", "content": "A massive northwest cloudband is forecast to bring widespread rainfall across approximately 80% of Australia from July 23\u201327, 2025,", "score": 0.585789, "raw_content": null}, {"url": "https://www.9news.com.au/weather", "title": "Australian National Weather Forecast - 9News", "content": "Show full warning Australian Government Bureau of Meteorology Tasmania TOP PRIORITY FOR IMMEDIATE BROADCAST Severe Weather Warning for Damaging Winds for King Island, Furneaux Islands, Western, Upper Derwent Valley, South East, North East, East Coast, North West Coast, Central North, Central Plateau and Midlands Forecast Districts. Show full warning Australian Government Bureau of Meteorology Victoria Warning to Sheep Graziers for North Central, North East, South West, Central, West and South Gippsland and East Gippsland forecast districts Issued at 10:42 AM EST on Friday 18 July 2025 Warning to Sheep Graziers for the following areas: North Central, North East, South West, Central, West and South Gippsland and East Gippsland forecast districts Sheep graziers are warned that cold temperatures, isolated showers and northerly winds are expected during Saturday.", "score": 0.2678698, "raw_content": null}, {"url": "https://www.miragenews.com/severe-weather-rain-damaging-winds-hit-australia-1502455/", "title": "Severe Weather: Rain, Damaging Winds Hit Australia | Mirage News", "content": "A broad reaching rain band is moving across the country, with damaging winds likely for some parts of Australia over the coming days as well", "score": 0.21368915, "raw_content": null}, {"url": "https://www.miragenews.com/weather-alert-wind-rain-to-ease-this-weekend-1503764/", "title": "Weather Alert: Wind, Rain to Ease This Weekend | Mirage News", "content": "It can be very dangerous to be out and about in that type of weather. Through the remainder of the day today, we'll see this band of rain move", "score": 0.09603416, "raw_content": null}]}
# inference> Based on the search results, it appears that there is a risk of rain and damaging winds in the Sydney area. The Australian Bureau of Meteorology has issued warnings for severe weather, including rain and damaging winds, for various parts of the country. It is recommended to check the latest weather forecast and warnings before traveling or engaging in outdoor activities.

# %% [markdown]
# ### ReAct Agent with websearch tool and client tool
#
# This section demonstrates the ReAct (Reasoning and Acting) framework in action.
#
# Here is a walkthrough of how the ReAct agent will tackle this same "weather near me" problem:
#
# When asked "Are there any weather-related risks in my area that could disrupt network connectivity or system availability?", the agent will:
#
# 1. **Reason** that it needs to get location information first.
# 2. **Act** by calling the `get_location` client tool.
# 3. **Observe** the location result.
# 4. **Reason** that it now needs to search for weather in that location.
# 5. **Act** by calling the `websearch` tool with observed location.
# 6. **Observe** and processes the search results into a final answer.
#
# Unlike prompt chaining which follows fixed steps, ReAct dynamically breaks down tasks and adapts its approach based on the results of each step. This makes it more flexible and capable of handling complex, real-world queries effectively.
#
# We are going to switch LLM models here from the LLM llama32-3b model to the more powerful reasoning model deepseek-r1-0528-qwen3-8b-bnb-4bit that is able to more accurately reason about the tools it will use. Resoning models output their \<thought\> process first.

# %%
model_id = "deepseek-r1-0528-qwen3-8b-bnb-4bit" # "llama-4-scout-17b-16e-w4a16", "llama3-2-3b"

agent = ReActAgent(
            client=client,
            model=model_id,
            tools=[get_location, "builtin::websearch"],
            response_format={
                "type": "json_schema",
                "json_schema": ReActOutput.model_json_schema(),
            },
            sampling_params=sampling_params,
        )
user_prompts = [
    "Are there any immediate weather-related risks in my area that could disrupt network connectivity or system availability?"
]
session_id = agent.create_session("web-session")
for prompt in user_prompts:
    cprint(f"Processing user query: {prompt}", "blue")
    print("="*50)
    response = agent.create_turn(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        session_id=session_id,
        stream=stream
    )
    if stream:
        for log in EventLogger().log(response):
            log.print()
    else:
        step_printer(response.steps) # print the steps of an agent's response in a formatted way.
# Out:
# Processing user query: Are there any immediate weather-related risks in my area that could disrupt network connectivity or system availability?
# ==================================================
# inference> {
#     "thought": "I need to determine if there are any immediate weather-related risks in the user's area. However, I don't have the user's location. I can use the get_location tool to get the user's location, but the tool description says 'Provide the location upon request.' and it has a parameter 'query' with a default value of 'location'. I should use the get_location tool to get the location first, then use that information to check for weather risks. But I don't have a tool to check weather. I only have web_search and get_location. I can use web_search to search for weather information after getting the location. However, the task is to check for weather-related risks that could disrupt network connectivity or system availability. I should first get the user's location, then use web_search to find weather information for that location.",
#     "action": {
#         "tool_name": "get_location",
#         "tool_params": [{"name": "query", "value": "location"}]
#     },
#     "answer": null
# }
# tool_execution> Tool:get_location Response:"Your current location is: Sydney, New South Wales, AU"
# inference> {
#     "thought": "I have received the user's location as Sydney, New South Wales, AU. Now I need to check for immediate weather-related risks in this area. I can use the web_search tool to search for weather information. I should search for 'weather in Sydney' to get the current weather conditions and see if there are any risks.",
#     "action": {
#         "tool_name": "brave_search",
#         "tool_params": [{"name": "query", "value": "weather in Sydney"}]
#     },
#     "answer": null
# }
# tool_execution> Tool:brave_search Response:Unknown tool `brave_search` was called.
# inference> {
#     "thought": "I apologize, but it seems there was an error in my tool call. The available tools are web_search and get_location. I mistakenly used 'brave_search' which does not exist. I should use the correct tool name. The correct tool for web search is 'web_search'. I will correct that and proceed.",
#     "action": {
#         "tool_name": "web_search",
#         "tool_params": [{"name": "query", "value": "weather in Sydney"}]
#     },
#     "answer": null
# }
# tool_execution> Tool:web_search Response:{"query": "weather in Sydney", "top_k": [{"title": "Weather in Sydney, Australia", "url": "https://www.weatherapi.com/", "content": "{'location': {'name': 'Sydney', 'region': 'New South Wales', 'country': 'Australia', 'lat': -33.8833, 'lon': 151.2167, 'tz_id': 'Australia/Sydney', 'localtime_epoch': 1753578322, 'localtime': '2025-07-27 11:05'}, 'current': {'last_updated_epoch': 1753578000, 'last_updated': '2025-07-27 11:00', 'temp_c': 15.6, 'temp_f': 60.1, 'is_day': 1, 'condition': {'text': 'Patchy rain nearby', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'wind_mph': 14.8, 'wind_kph': 23.8, 'wind_degree': 306, 'wind_dir': 'NW', 'pressure_mb': 1005.0, 'pressure_in': 29.69, 'precip_mm': 0.01, 'precip_in': 0.0, 'humidity': 54, 'cloud': 88, 'feelslike_c': 15.6, 'feelslike_f': 60.1, 'windchill_c': 15.6, 'windchill_f': 60.1, 'heatindex_c': 15.6, 'heatindex_f': 60.1, 'dewpoint_c': 6.4, 'dewpoint_f': 43.5, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 2.5, 'gust_mph': 17.5, 'gust_kph': 28.2}}", "score": 0.9758558, "raw_content": null}, {"url": "https://www.weather25.com/oceania/australia?page=date&date=27-7", "title": "Australia weather forecast for Sunday, 27 July 2025 - Weather25.com", "content": "Hourly weather forecast for Sunday, 27 July 2025 ; 12\u00b0C \u00b7 11\u00b0C \u00b7 11\u00b0C \u00b7 13\u00b0C ; Clear. Clear. Clear. Sunny.", "score": 0.86954874, "raw_content": null}, {"url": "https://watchers.news/2025/07/23/rain-australia-major-weather-system-july-2025/", "title": "Rain expected across most of Australia as major weather system ...", "content": "A massive northwest cloudband is forecast to bring widespread rainfall across approximately 80% of Australia from July 23\u201327, 2025,", "score": 0.7065353, "raw_content": null}, {"url": "http://www.bom.gov.au/climate/dwo/202507/html/IDCJDW2163.202507.shtml", "title": "Sydney Harbour, NSW - July 2025 - Daily Weather Observations", "content": "Sydney Harbour, New South Wales July 2025 Daily Weather Observations. Date, Day, Temps, Rain, Evap, Sun, Max wind gust, 9 am, 3 pm. Min, Max, Dir, Spd, Time", "score": 0.5408517, "raw_content": null}, {"url": "http://www.bom.gov.au/climate/dwo/IDCJDW2124.latest.shtml", "title": "Sydney, NSW - Daily Weather Observations - Bureau of Meteorology", "content": "# Sydney, New South Wales May 2025 Daily Weather Observations Most observations from Observatory Hill, but some from Fort Denison and Sydney Airport. To print this page, get the PDF version file, for printing\") (one page, 45 kb). The last 14 months of Daily Weather Observations for Sydney, New South Wales are also here on this web site: Daily Weather Observations are also routinely prepared for hundreds of other locations in New South Wales and across Australia. If you are after long-term averages relevant to Sydney, New South Wales, look at the tables for Sydney (Observatory Hill) {station 066062}\"), Centennial Park Round House or Sydney Airport AMO. If you are using these pages, you are deemed to have understood the important information in these notes.", "score": 0.2944538, "raw_content": null}]}
# inference> {
#     "thought": "I have the search results for 'weather in Sydney'. I need to check if there are any immediate weather-related risks that could disrupt network connectivity or system availability. Looking at the search results, the first one shows current weather in Sydney with temperature 15.6°C and condition 'Patchy rain nearby'. The second result shows hourly forecast with clear conditions. The third result mentions a major weather system bringing rain across Australia from July 23-27, but the current date is July 27, so this might be for the upcoming days. The fourth and fifth results are about historical weather observations. Currently, the weather in Sydney is patchy rain nearby, but not severe. There is no mention of severe weather events like storms, floods, or high winds that could disrupt network connectivity. Therefore, there are no immediate weather-related risks in Sydney.",
#     "action": null,
#     "answer": "Based on the current weather information for Sydney, there are no immediate weather-related risks that could disrupt network connectivity or system availability. The current conditions are patchy rain nearby, but no severe weather events are expected."
# }

# %% [markdown]
# ## Key Takeaways
# - This notebook demonstrated how to build more capable agents using Prompt Chaining and the ReAct framework.
# - It showed how agents can maintain context across multiple steps and perform structured, multi-step reasoning.
# - It highlights how ReAct enables dynamic tool selection and adaptive decision-making based on intermediate results.
# - These techniques enhance agent autonomy and make them more suitable for complex operational tasks.
#
# For further extensions, continue exploring in the next notebook: [Agents and MCP](Level4_agents_and_mcp.ipynb).
